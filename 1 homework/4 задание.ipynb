# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-np.pi, np.pi, 201)

K = [1,10]

def showCos(k):
    plt.plot(x,np.cos(k*x))
    plt.xlabel('x')
    plt.ylabel('y')
    plt.axis('tight')

for k in K:
    showCos(k)
