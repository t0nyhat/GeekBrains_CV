# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(-np.pi, np.pi, 201)
K = [1,10,20,3]

for k in K:
    showCos(k)

def showCos(m):
    plt.plot(x,np.cos(m*x))
    plt.xlabel('x')
    plt.ylabel('y')
    plt.show()
